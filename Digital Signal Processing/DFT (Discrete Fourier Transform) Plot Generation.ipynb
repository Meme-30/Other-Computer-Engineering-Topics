# %% [markdown]
# ICE2 / "In class" experiment 2
#
# Well, this ICE is designed to be done at home 😀

# %%
# START MY TI-84 CALCULATOR
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# We have an analog sinusoidal signal, $x(t)$, of frequency $f_1$ Hz.
#
# It is sampled at $f_s$ Hz.
#
# We acquire $N$ samples.
#
# We try to estimate the frequency $f_1$ by looking at the plot of DFT.
#
# TO GET FULL CREDIT, YOU NEED TO WRITE DETAILED AND MEANINGFUL COMMENTS.
#
# YOU NEED TO TRY SEVERAL DIFFERENT CASES, MAKE OBSERVATIONS, AND THEN SUMMARIZE YOUR OBSERVATIONS.
#
# 1. Try at least two cases where $f_1 < f_s/2$ is satisfied and not satisfied. Summarize your observations (Include plots).
#
# 2. Try at least two cases where $N$ is less than 20 and $N$ is larger than 200. Summarize your observations (Include plots).
#
# 3. When you zoom into the DFT plot, do you see the peak location at $f_1$, close to $f_1$ or quite different from $f_1$. What is the effect of increasing the number of samples ? Include plots.

# %%
# Sampling freq
fs = 2000
# Freq of analog signal
f1 = 304
# Number of samples acquired
N = 100

# DO NOT EDIT BELOW THIS LINE

# %%
Ts = 1 / fs

# Draw hi-res y(t)
nval = np.arange(0, N * 20)
tval = np.arange(0, N * 20) * (Ts / 20)
yval = np.sin(2 * np.pi * f1 * tval)

plt.figure(figsize=(18, 6), dpi=80)
plt.plot(tval, yval)
plt.xlabel('t')
plt.ylabel('y')
plt.grid(True)

# Draw samples
nval = np.arange(0, N)
tval = np.arange(0, N) * Ts
xval = np.sin(2 * np.pi * f1 * tval)

plt.stem(tval, xval)
plt.grid(True)

plt.plot(nval * Ts, xval, 'ro')
# Out:
# <ipython-input-82-641eb326d275>:19: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(tval, xval)

# %%
X = np.fft.fft(xval)
freq = np.fft.fftfreq(len(X)) * fs
plt.figure(figsize=(16,12))
plt.stem(freq, np.abs(X)**2)
plt.plot(freq, np.abs(X)**2,'r-')
plt.grid()
#plt.xlim([280,320])
plt.title('DFT plot')
# Out:
# <ipython-input-83-728c5a6ba4a3>:4: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(freq, np.abs(X)**2)
# Text(0.5, 1.0, 'DFT plot')

# %%
X = np.fft.fft(xval)
freq = np.fft.fftfreq(len(X)) * fs
plt.figure(figsize=(16,12))
plt.stem(freq, np.abs(X)**2)
plt.plot(freq, np.abs(X)**2,'r-')
plt.grid()
plt.xlim([200,390])
plt.title('DFT plot (zoom)')
# Out:
# <ipython-input-84-2858221d6ab8>:4: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(freq, np.abs(X)**2)
# Text(0.5, 1.0, 'DFT plot (zoom)')
